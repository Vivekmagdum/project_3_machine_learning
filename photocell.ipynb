# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    H(h)_m  H(i_opt)_m  H(i)_m  Hb(n)_m    Kd   T2m
# 0  168.30      214.89  195.95   234.66  0.20  24.1
# 1  172.96      203.07  157.65   218.61  0.20  25.4
# 2  213.37      225.63  133.62   251.01  0.20  27.3
# 3  198.51      189.55   78.05   206.63  0.23  28.5
# 4  202.59      179.50   51.01   201.88  0.25  28.4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   H(h)_m      216 non-null    float64
#  1   H(i_opt)_m  216 non-null    float64
#  2   H(i)_m      216 non-null    float64
#  3   Hb(n)_m     216 non-null    float64
#  4   Kd          216 non-null    float64
#  5   T2m         216 non-null    float64
# dtypes: float64(6)
# memory usage: 10.3 KB

# %% [markdown]
# ## Test, train spliting

# %%
from sklearn.model_selection import train_test_split
train_set, test_set  = train_test_split(data, test_size=0.2, random_state=42)
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 172
# Rows in test set: 44

# %%
train_set_x=train_set.drop(columns=["T2m"])

# %%
train_set_y=train_set["T2m"]

# %%
test_set_x=train_set.drop(columns=["T2m"])

# %%
test_set_y=train_set["T2m"]

# %%
train_set_x.shape
# Out:
# (172, 5)

# %% [markdown]
# ## Creating model

# %%
#Add this model which more accurate
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
# model = LinearRegression()
# model = DecisionTreeRegressor()
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(train_set_x, train_set_y)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ## Making the predation

# %%
y_pred=model.predict(test_set_x)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test_set_y, y_pred)
rmse = np.sqrt(mse)

# %%
mse
# Out:
# 0.08737217441860465

# %%
rmse
# Out:
# 0.2955878455190684

# %%
n=model.predict([[202.59,179.50,51.01,201.88,0.25]]) # get the feture if you are manauually want to get feature
# Out:
# C:\Users\vivek magdum\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
n
# Out:
# array([28.166])
